# %% [markdown]
# # Load infants data

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import os
import glob

path = "/content/gdrive/MyDrive/WOA7015 project final/data"

df1 = pd.DataFrame()
for i in range(5):
  csv_file = os.path.join(path, f"processed_infant1_segment{i}.csv")
  df_temp = pd.read_csv(csv_file)
  df1 = df1.append(df_temp, ignore_index=True)
df1
# Out:
#        heart_rate  respiratory data  filtered respiratory data  \
# 0      157.285422         24.174376                   0.103385
# 1      153.943229         23.670994                  -0.012251
# 2      154.713585         23.725009                  -0.057214
# 3      154.095116         23.590208                  -0.128316
# 4      154.383814         23.561798                  -0.182994
# ...           ...               ...                        ...
# 35345  147.069832         24.591811                   0.201204
# 35346  147.317057         24.569438                   0.186234
# 35347  146.957840         24.595816                   0.152470
# 35348  147.406014         24.630728                   0.135676
# 35349  146.570928         24.621560                   0.088973
#
#        respiratory rate
# 0             67.217080
# 1             58.055828
# 2             60.936149
# 3             59.919750
# 4             61.347608
# ...                 ...
# 35345         49.712404
# ...

# %%
df2 = pd.DataFrame()
for i in range(5):
  csv_file = os.path.join(path, f"processed_infant2_segment{i}.csv")
  df_temp = pd.read_csv(csv_file)
  df2 = df2.append(df_temp, ignore_index=True)
df2
# Out:
#        heart_rate  respiratory data  filtered respiratory data  \
# 0      119.298998          23.00123                    0.01396
# 1      119.535054          22.95210                   -0.02545
# 2      119.443306          22.91069                   -0.06152
# 3      119.459338          22.86437                   -0.09138
# 4      119.412903          22.82015                   -0.11341
# ...           ...               ...                        ...
# 33495  116.979139          22.37376                   -0.48760
# 33496  116.688085          22.46289                   -0.42672
# 33497  116.706796          22.54501                   -0.34738
# 33498  116.209555          22.64117                   -0.25466
# 33499  116.408734          22.72610                   -0.15448
#
#        respiratory rate
# 0             57.692308
# 1             58.012691
# 2             58.320730
# 3             58.616577
# 4             58.900384
# ...                 ...
# 33495         56.912766
# ...

# %%
df3 = pd.DataFrame()
for i in range(5):
  csv_file = os.path.join(path, f"processed_infant3_segment{i}.csv")
  df_temp = pd.read_csv(csv_file)
  df3 = df3.append(df_temp, ignore_index=True)
df3
# Out:
#        heart_rate  respiratory data  filtered respiratory data  \
# 0      114.196198          21.64776                   -0.02518
# 1      113.045336          21.70290                   -0.04260
# 2      113.373279          21.65613                   -0.06198
# 3      113.223990          21.65753                   -0.08460
# 4      113.374170          21.61705                   -0.11006
# ...           ...               ...                        ...
# 48245  128.266398          22.17545                   -0.13290
# 48246  128.094325          22.08401                   -0.13744
# 48247  128.119871          22.04981                   -0.11582
# 48248  127.833918          21.95418                   -0.07316
# 48249  127.985133          21.91998                   -0.01671
#
#        respiratory rate
# 0             47.619048
# 1             47.790726
# 2             47.954233
# 3             48.109688
# 4             48.257205
# ...                 ...
# 48245         44.433285
# ...

# %%
df4 = pd.DataFrame()
for i in range(5):
  csv_file = os.path.join(path, f"processed_infant4_segment{i}.csv")
  df_temp = pd.read_csv(csv_file)
  df4 = df4.append(df_temp, ignore_index=True)
df4
# Out:
#        heart_rate  respiratory data  filtered respiratory data  \
# 0      158.975203          15.01354                    0.08634
# 1      156.802408          15.04400                    0.09809
# 2      157.472737          15.10281                    0.11599
# 3      157.204201          15.19293                    0.14444
# 4      157.505446          15.34481                    0.18512
# ...           ...               ...                        ...
# 36245  155.046191          15.19293                   -0.20893
# 36246  155.186792          15.25173                   -0.17685
# 36247  155.096261          15.28220                   -0.15439
# 36248  155.364697          15.37316                   -0.13957
# 36249  155.122556          15.42901                   -0.12896
#
#        respiratory rate
# 0             69.767442
# 1             70.676281
# 2             71.523961
# 3             72.311766
# 4             73.040984
# ...                 ...
# 36245         40.981192
# ...

# %%
df5 = pd.DataFrame()
for i in range(5):
  csv_file = os.path.join(path, f"processed_infant5_segment{i}.csv")
  df_temp = pd.read_csv(csv_file)
  df5 = df5.append(df_temp, ignore_index=True)
df5
# Out:
#        heart_rate  respiratory data  filtered respiratory data  \
# 0      136.678862          30.29052                   -0.08238
# 1      138.366538          30.29450                   -0.08902
# 2      138.534842          30.30048                   -0.09659
# 3      139.163690          30.24171                   -0.10605
# 4      139.410952          30.30845                   -0.11812
# ...           ...               ...                        ...
# 42495  143.021353          30.89121                    0.41072
# 42496  143.223002          30.88922                    0.37900
# 42497  142.852476          30.80155                    0.32976
# 42498  143.242627          30.74377                    0.26691
# 42499  142.423306          30.74079                    0.19607
#
#        respiratory rate
# 0             37.037037
# 1             37.080565
# 2             37.122278
# 3             37.162201
# 4             37.200364
# ...                 ...
# 42495         63.269719
# ...

# %%
df6 = pd.DataFrame()
for i in range(5):
  csv_file = os.path.join(path, f"processed_infant6_segment{i}.csv")
  df_temp = pd.read_csv(csv_file)
  df6 = df6.append(df_temp, ignore_index=True)
df6
# Out:
#        heart_rate  respiratory data  filtered respiratory data  \
# 0      139.535707          19.63788                    0.08834
# 1      139.573467          19.53755                   -0.01621
# 2      139.606573          19.50024                   -0.11650
# 3      139.633323          19.49412                   -0.20607
# 4      139.655051          19.45742                   -0.27560
# ...           ...               ...                        ...
# 33995  127.769906          19.93029                   -0.10413
# 33996  128.005170          19.97127                   -0.09947
# 33997  127.646435          19.97005                   -0.09226
# 33998  128.061497          19.93151                   -0.08305
# 33999  127.224124          19.96638                   -0.07256
#
#        respiratory rate
# 0            102.731572
# 1            102.731572
# 2            102.076418
# 3            101.481235
# 4            100.944445
# ...                 ...
# 33995         43.408614
# ...

# %%
df7 = pd.DataFrame()
for i in range(5):
  csv_file = os.path.join(path, f"processed_infant7_segment{i}.csv")
  df_temp = pd.read_csv(csv_file)
  df7 = df7.append(df_temp, ignore_index=True)
df7
# Out:
#        heart_rate  respiratory data  filtered respiratory data  \
# 0      158.785971          14.82356                   -0.04129
# 1      172.107111          14.79397                   -0.03447
# 2      169.210740          14.76128                   -0.03025
# 3      171.370233          14.70989                   -0.03059
# 4      170.101822          14.65656                   -0.03735
# ...           ...               ...                        ...
# 46245  153.082419          14.65189                    0.22921
# 46246  154.226891          14.68070                    0.20049
# 46247  152.848511          14.73870                    0.15443
# 46248  154.905856          14.71690                    0.09422
# 46249  151.588725          14.65189                    0.02474
#
#        respiratory rate
# 0             38.809463
# 1             38.809463
# 2             38.169158
# 3             37.552491
# 4             36.959185
# ...                 ...
# 46245         68.295558
# ...

# %%
df8 = pd.DataFrame()
for i in range(5):
  csv_file = os.path.join(path, f"processed_infant8_segment{i}.csv")
  df_temp = pd.read_csv(csv_file)
  df8 = df8.append(df_temp, ignore_index=True)
df8
# Out:
#        heart_rate  respiratory data  filtered respiratory data  \
# 0      131.638024          16.65482                   -0.02963
# 1      132.302567          16.87844                    0.16580
# 2      132.180978          16.92544                    0.35565
# 3      132.304798          17.13175                    0.53492
# 4      132.263995          17.28858                    0.69892
# ...           ...               ...                        ...
# 32495  135.020861          15.91568                   -0.28478
# 32496  135.304493          15.93498                   -0.25322
# 32497  134.935465          15.99435                   -0.20156
# 32498  135.448305          16.04382                   -0.13446
# 32499  134.575009          16.08884                   -0.05858
#
#        respiratory rate
# 0            111.111111
# 1            112.156425
# 2            113.083679
# 3            113.895919
# 4            114.596192
# ...                 ...
# 32495         17.436851
# ...

# %%
df9 = pd.DataFrame()
for i in range(5):
  csv_file = os.path.join(path, f"processed_infant9_segment{i}.csv")
  df_temp = pd.read_csv(csv_file)
  df9 = df9.append(df_temp, ignore_index=True)
df9
# Out:
#        heart_rate  respiratory data  filtered respiratory data  \
# 0      131.795074          27.74759                    0.06457
# 1      135.940868          27.68516                    0.02268
# 2      135.051986          27.75318                   -0.00546
# 3      135.773632          27.74946                   -0.00931
# 4      135.446624          27.86034                    0.01621
# ...           ...               ...                        ...
# 29995  132.060012          28.80983                    0.33992
# 29996  132.505927          28.86760                    0.31342
# 29997  132.135240          28.92257                    0.28967
# 29998  132.896406          28.91325                    0.26823
# 29999  131.910496          28.99525                    0.24719
#
#        respiratory rate
# 0             67.849563
# 1             67.849563
# 2             66.072293
# 3             64.432483
# 4             62.926984
# ...                 ...
# 29995         47.343268
# ...

# %%
df10 = pd.DataFrame()
for i in range(5):
  csv_file = os.path.join(path, f"processed_infant10_segment{i}.csv")
  df_temp = pd.read_csv(csv_file)
  df10 = df10.append(df_temp, ignore_index=True)
df10
# Out:
#        heart_rate  respiratory data  filtered respiratory data  \
# 0      136.031958          31.48467                   -0.10981
# 1      131.218175          31.47863                   -0.18171
# 2      132.249242          31.49170                   -0.25083
# 3      131.412483          31.55304                   -0.31381
# 4      131.797243          31.54902                   -0.36531
# ...           ...               ...                        ...
# 38745  134.433566          31.10358                   -1.22333
# 38746  134.201572          31.42132                   -1.06633
# 38747  134.114204          31.68074                   -0.87130
# 38748  133.758314          31.67471                   -0.64985
# 38749  133.738299          31.93413                   -0.41422
#
#        respiratory rate
# 0             32.967033
# 1             33.013658
# 2             33.058322
# 3             33.101050
# 4             33.141870
# ...                 ...
# 38745         60.030462
# ...

# %% [markdown]
# Infant10 data contains cases where the heart rate is less than 0, which is an outlier and needs to be deleted.

# %%
df10 = df10.loc[df10["heart_rate"] > 0].reset_index(drop=True)
df10
# Out:
#        heart_rate  respiratory data  filtered respiratory data  \
# 0      136.031958          31.48467                   -0.10981
# 1      131.218175          31.47863                   -0.18171
# 2      132.249242          31.49170                   -0.25083
# 3      131.412483          31.55304                   -0.31381
# 4      131.797243          31.54902                   -0.36531
# ...           ...               ...                        ...
# 35548  134.433566          31.10358                   -1.22333
# 35549  134.201572          31.42132                   -1.06633
# 35550  134.114204          31.68074                   -0.87130
# 35551  133.758314          31.67471                   -0.64985
# 35552  133.738299          31.93413                   -0.41422
#
#        respiratory rate
# 0             32.967033
# 1             33.013658
# 2             33.058322
# 3             33.101050
# 4             33.141870
# ...                 ...
# 35548         60.030462
# ...

# %% [markdown]
# # Split the dataset
# We choose infant3 and infant4 as test dataset, and others as train dataset.

# %%
train_df = pd.DataFrame()
train_df = train_df.append([df1, df2, df5, df6, df7, df8, df9, df10], ignore_index=True)
test_df = pd.DataFrame()
test_df = test_df.append([df4, df3], ignore_index=True)
print(len(train_df), len(test_df))
train_df
# Out:
# 289653 84500
#         heart_rate  respiratory data  filtered respiratory data  \
# 0       157.285422         24.174376                   0.103385
# 1       153.943229         23.670994                  -0.012251
# 2       154.713585         23.725009                  -0.057214
# 3       154.095116         23.590208                  -0.128316
# 4       154.383814         23.561798                  -0.182994
# ...            ...               ...                        ...
# 289648  134.433566         31.103580                  -1.223330
# 289649  134.201572         31.421320                  -1.066330
# 289650  134.114204         31.680740                  -0.871300
# 289651  133.758314         31.674710                  -0.649850
# 289652  133.738299         31.934130                  -0.414220
#
#         respiratory rate
# 0              67.217080
# 1              58.055828
# 2              60.936149
# 3              59.919750
# 4              61.347608
# ...

# %% [markdown]
# # Models Training and Evaluation

# %% [markdown]
# -----
# -----
# ## Linear Regression model

# %%
#importing necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt
import numpy as np

X_train = train_df.drop("heart_rate", axis=1)
X_test = test_df.drop("heart_rate", axis=1)
y_train = train_df["heart_rate"]
y_test = test_df["heart_rate"]

# normalize the dataset
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

#building the model
model = LinearRegression()

#fitting the model on training data
model.fit(X_train, y_train)

#predicting on test data
y_pred = model.predict(X_test)

#verifying the results
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, y_pred)))
print('Coefficient of Determination', r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 10.723372542584533
# Mean Squared Error: 139.61316934357114
# Root Mean Squared Error: 11.815801680104958
# Coefficient of Determination 0.5921349204732023

# %%
X_train = train_df[["respiratory rate"]]
X_test = test_df[["respiratory rate"]]
y_train = train_df["heart_rate"]
y_test = test_df["heart_rate"]

# normalize the dataset
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

#building the model
model = LinearRegression()

#fitting the model on training data
model.fit(X_train, y_train)

#predicting on test data
y_pred = model.predict(X_test)

#verifying the results
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, y_pred)))
print('Coefficient of Determination', r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 17.530392302427092
# Mean Squared Error: 342.7557784906049
# Root Mean Squared Error: 18.513664642382526
# Coefficient of Determination -0.0013246852688642008

# %%
X_train = train_df[["respiratory data"]]
X_test = test_df[["respiratory data"]]
y_train = train_df["heart_rate"]
y_test = test_df["heart_rate"]

# normalize the dataset
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

#building the model
model = LinearRegression()

#fitting the model on training data
model.fit(X_train, y_train)

#predicting on test data
y_pred = model.predict(X_test)

#verifying the results
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, y_pred)))
print('Coefficient of Determination', r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 8.81054008373745
# Mean Squared Error: 95.1436636639309
# Root Mean Squared Error: 9.7541613511327
# Coefficient of Determination 0.7220478689136858

# %%
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (20,5)
plt.plot(y_train, label='train actual')
plt.plot(model.predict(X_train), label='train prediction', color='red')
plt.title('Training set')
plt.xlabel('time')
plt.ylabel('value')
plt.legend()
plt.show()

# %%
plt.plot(y_test, label='actual')
plt.plot(y_pred, label='prediction', color='red')
plt.title('Testing set')
plt.xlabel('time')
plt.ylabel('value')
plt.legend()
plt.show()

# %% [markdown]
# -----
# -----
# ## XGBoost Model

# %%
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV

X_train = train_df[["respiratory data"]]
X_test = test_df[["respiratory data"]]
y_train = train_df["heart_rate"]
y_test = test_df["heart_rate"]

# normalize the dataset
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

xgb_model = XGBRegressor(objective='reg:squarederror')

# define hyperparameters to tune
params = {
    'max_depth': [1, 2, 3, 4, 5],
    'learning_rate': [0.1, 0.2, 0.3],
    'n_estimators': [10, 20, 25, 30],
}

# set up grid search
grid_search = GridSearchCV(estimator=xgb_model, param_grid=params, cv=5, n_jobs=-1)

# fit grid search to training data
grid_search.fit(X_train, y_train)

# print best combination of hyperparameters
print(grid_search.best_params_)
# Out:
# {'learning_rate': 0.2, 'max_depth': 1, 'n_estimators': 25}

# %%
model_xgb = XGBRegressor(max_depth=grid_search.best_params_['max_depth'],
                         learning_rate=grid_search.best_params_['learning_rate'],
                         n_estimators=grid_search.best_params_['n_estimators'],
                         seed=22,
                         objective='reg:squarederror')
model_xgb.fit(X_train, y_train)

# make predictions on test set
predictions = model_xgb.predict(X_test)

print("Mean Absolute Error:", mean_absolute_error(y_test, predictions))
print("Mean Squared Error:", mean_squared_error(y_test, predictions))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, predictions)))
print('Coefficient of Determination', r2_score(y_test, predictions))
# Out:
# Mean Absolute Error: 15.992607743768021
# Mean Squared Error: 305.02457442392154
# Root Mean Squared Error: 17.464952746111898
# Coefficient of Determination 0.10890302906250082

# %%
plt.plot(y_test, label='actual')
plt.plot(predictions, label='prediction', color='red')
plt.title('Testing set')
plt.xlabel('time')
plt.ylabel('value')
plt.legend()
plt.show()

# %% [markdown]
# ------
# ------
# ## LSTM model

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler

train_dfl = pd.DataFrame()
train_dfl = train_dfl.append([df1, df2, df5, df7, df6, df8, df9, df10], ignore_index=True)
# val_dfl = pd.DataFrame()
# val_dfl = val_dfl.append([df1, df2], ignore_index=True)
test_dfl = pd.DataFrame()
test_dfl = test_dfl.append([df3, df4], ignore_index=True)

df_r = train_dfl.astype('float32')
X_train = df_r.drop("heart_rate", axis=1)
y_train = df_r[["heart_rate"]]

# df_v = val_dfl.astype('float32')
# X_val = df_v.drop("heart_rate", axis=1)
# y_val = df_v[["heart_rate"]]

df_t = test_dfl.astype('float32')
X_test = df_t.drop("heart_rate", axis=1)
y_test = df_t[["heart_rate"]]

# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
X_train = scaler.fit_transform(X_train)
# X_val = scaler.fit_transform(X_val)
X_test = scaler.fit_transform(X_test)

# reshape input to be [samples, time steps, features]
X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
# X_val = X_val.reshape(X_val.shape[0], 1, X_val.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
# print(len(X_train), len(X_val), len(X_test))
print(len(X_train), len(X_test))

# create and fit the LSTM network
model_lstm = Sequential()
model_lstm.add(LSTM(4, batch_input_shape=(1, X_train.shape[1], X_train.shape[2])))
model_lstm.add(Dense(1))
model_lstm.compile(loss='mean_squared_error', optimizer='adam')
model_lstm.summary()
# Out:
# 289653 84500
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_1 (LSTM)               (1, 4)                    128
#
#  dense_1 (Dense)             (1, 1)                    5
#
# ...
# Total params: 133
# Trainable params: 133
# Non-trainable params: 0
# _________________________________________________________________

# %%
# history = model_lstm.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, batch_size=64, verbose=1, shuffle=False)
history = model_lstm.fit(X_train, y_train, epochs=10, batch_size=32, verbose=1, shuffle=False)
# Out:
# Epoch 1/10
# 9052/9052 [==============================] - 20s 2ms/step - loss: 14067.2637
# Epoch 2/10
# 9052/9052 [==============================] - 17s 2ms/step - loss: 7312.0015
# Epoch 3/10
# 9052/9052 [==============================] - 17s 2ms/step - loss: 3160.4436
# Epoch 4/10
# 9052/9052 [==============================] - 21s 2ms/step - loss: 1234.5854
# Epoch 5/10
# 9052/9052 [==============================] - 24s 3ms/step - loss: 716.8688
# Epoch 6/10
# 9052/9052 [==============================] - 22s 2ms/step - loss: 648.4524
# Epoch 7/10
# 9052/9052 [==============================] - 21s 2ms/step - loss: 642.1738
# Epoch 8/10
# 9052/9052 [==============================] - 21s 2ms/step - loss: 641.3364
# Epoch 9/10
# 9052/9052 [==============================] - 19s 2ms/step - loss: 641.2116
# Epoch 10/10
# 9052/9052 [==============================] - 18s 2ms/step - loss: 641.1918

# %%
testPredict = model_lstm.predict(X_test, batch_size=1)
testPredict
# Out:
# 84500/84500 [==============================] - 114s 1ms/step
# array([[132.58954],
#        [132.58954],
#        [132.58954],
#        ...,
#        [132.58951],
#        [132.58952],
#        [132.58952]], dtype=float32)

# %%
# calculate root mean squared error
print("Mean Absolute Error:", mean_absolute_error(y_test, testPredict))
print("Mean Squared Error:", mean_squared_error(y_test, testPredict))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, testPredict)))
print('Coefficient of Determination', r2_score(y_test, testPredict))
# Out:
# Mean Absolute Error: 17.423498
# Mean Squared Error: 358.46164
# Root Mean Squared Error: 18.933083
# Coefficient of Determination -0.04720763719654064

# %%
pd.DataFrame(history.history).plot(figsize=(8,5))
plt.show()

# %%
plt.plot(y_test, label='actual')
plt.plot(testPredict, label='prediction', color='red')
plt.title('Testing set')
plt.xlabel('time')
plt.ylabel('value')
plt.legend()
plt.show()
