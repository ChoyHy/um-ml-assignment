# %% [markdown]
# # Prerequisite

# %% [markdown]
# ## Install for Google Colab

# %% [markdown]
# ## install wfdb library

# %%
# %pip install wfdb
# Out:
# Requirement already satisfied: wfdb in c:\users\dd\appdata\local\programs\python\python311\lib\site-packages (4.1.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: SoundFile<0.12.0,>=0.10.0 in c:\users\dd\appdata\local\programs\python\python311\lib\site-packages (from wfdb) (0.11.0)
# Requirement already satisfied: matplotlib<4.0.0,>=3.2.2 in c:\users\dd\appdata\local\programs\python\python311\lib\site-packages (from wfdb) (3.6.2)
# Requirement already satisfied: numpy<2.0.0,>=1.10.1 in c:\users\dd\appdata\local\programs\python\python311\lib\site-packages (from wfdb) (1.24.1)
# Requirement already satisfied: pandas<2.0.0,>=1.0.0 in c:\users\dd\appdata\local\programs\python\python311\lib\site-packages (from wfdb) (1.5.2)
# Requirement already satisfied: requests<3.0.0,>=2.8.1 in c:\users\dd\appdata\local\programs\python\python311\lib\site-packages (from wfdb) (2.28.1)
# Requirement already satisfied: scipy<2.0.0,>=1.0.0 in c:\users\dd\appdata\local\programs\python\python311\lib\site-packages (from wfdb) (1.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dd\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->wfdb) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\dd\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->wfdb) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dd\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->wfdb) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dd\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->wfdb) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dd\appdata\roaming\python\python311\site-packages (from matplotlib<4.0.0,>=3.2.2->wfdb) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dd\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->wfdb) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dd\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->wfdb) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dd\appdata\roaming\python\python311\site-packages (from matplotlib<4.0.0,>=3.2.2->wfdb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dd\appdata\local\programs\python\python311\lib\site-packages (from pandas<2.0.0,>=1.0.0->wfdb) (2022.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\dd\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.8.1->wfdb) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dd\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.8.1->wfdb) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dd\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.8.1->wfdb) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dd\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.8.1->wfdb) (2022.12.7)
# Requirement already satisfied: cffi>=1.0 in c:\users\dd\appdata\local\programs\python\python311\lib\site-packages (from SoundFile<0.12.0,>=0.10.0->wfdb) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\dd\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.0->SoundFile<0.12.0,>=0.10.0->wfdb) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\dd\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.2.2->wfdb) (1.16.0)

# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np

# Matplotlib
from IPython.display import display
import matplotlib.pyplot as plt
# %matplotlib inline

# Read file
import os

# Read ECG and Respiratory File
import wfdb
from wfdb import processing

# %% [markdown]
# ## Constant

# %%
data_folder_path = "./data/"

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Download Data

# %%
# wfdb.dl_database(db_dir='picsdb', dl_dir=data_folder_path, records='all', annotators='all', keep_subdirs=False, overwrite=False)

# %% [markdown]
# ## Read File

# %%
# infant_id = 1
ecg_path = []
resp_path = []
ecg_data = []
resp_data = []
for infant_id in range(1, 11):
    ecg_path.append(os.path.join(data_folder_path, f"infant{infant_id}_ecg"))
    resp_path.append(os.path.join(data_folder_path, f"infant{infant_id}_resp"))

    ecg_data.append(wfdb.rdrecord(ecg_path[infant_id-1]))
    resp_data.append(wfdb.rdrecord(resp_path[infant_id-1]))
    
print(ecg_path)
print(resp_path)
# Out:
# ['./data/infant1_ecg', './data/infant2_ecg', './data/infant3_ecg', './data/infant4_ecg', './data/infant5_ecg', './data/infant6_ecg', './data/infant7_ecg', './data/infant8_ecg', './data/infant9_ecg', './data/infant10_ecg']
# ['./data/infant1_resp', './data/infant2_resp', './data/infant3_resp', './data/infant4_resp', './data/infant5_resp', './data/infant6_resp', './data/infant7_resp', './data/infant8_resp', './data/infant9_resp', './data/infant10_resp']

# %% [markdown]
# ### Analyse File

# %%
wfdb.plot_wfdb(record=ecg_data[8])

# %%
signals, fields = wfdb.rdsamp(ecg_path[0])

# %%
signals
# Out:
# array([[-0.01998352],
#        [-0.01998352],
#        [-0.01498764],
#        ...,
#        [-0.31474046],
#        [-0.07868511],
#        [ 0.33597295]])

# %%
fields
# Out:
# {'fs': 250,
#  'sig_len': 41052191,
#  'n_sig': 1,
#  'base_date': None,
#  'base_time': None,
#  'units': ['mV'],
#  'sig_name': ['ECG'],
#  'comments': []}

# %%
# Extra informations
record = wfdb.rdheader(ecg_path[0])
record.__dict__
# Out:
# {'record_name': 'infant1_ecg',
#  'n_sig': 1,
#  'fs': 250,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 41052191,
#  'base_time': None,
#  'base_date': None,
#  'comments': [],
#  'sig_name': ['ECG'],
#  'p_signal': None,
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['infant1_ecg.dat'],
#  'fmt': ['16'],
#  'samps_per_frame': [1],
#  'skew': [None],
#  'byte_offset': [None],
#  'adc_gain': [800.6597],
#  'baseline': [28],
#  'units': ['mV'],
#  'adc_res': [0],
#  'adc_zero': [0],
#  'init_value': [12],
#  'checksum': [-25872],
#  'block_size': [0]}

# %% [markdown]
# ## Peak detection

# %%
def peaks_hr(sig, peak_inds, fs, title, figsize=(20, 10), saveto=None):
    "Plot a signal with its peaks and heart rate"
    # Calculate heart rate
    hrs = processing.hr.compute_hr(sig_len=sig.shape[0], qrs_inds=peak_inds, fs=fs)
    
    N = sig.shape[0]
    
    fig, ax_left = plt.subplots(figsize=figsize)
    ax_right = ax_left.twinx()
    
    ax_left.plot(sig, color='#3979f0', label='Signal')
    ax_left.plot(peak_inds, sig[peak_inds], 'rx', marker='x', 
                 color='#8b0000', label='Peak', markersize=12)
    ax_right.plot(np.arange(N), hrs, label='Heart rate', color='m', linewidth=2)

    ax_left.set_title(title)

    ax_left.set_xlabel('Time (ms)')
    ax_left.set_ylabel('ECG (mV)', color='#3979f0')
    ax_right.set_ylabel('Heart rate (bpm)', color='m')
    # Make the y-axis label, ticks and tick labels match the line color.
    ax_left.tick_params('y', colors='#3979f0')
    ax_right.tick_params('y', colors='m')
    if saveto is not None:
        plt.savefig(saveto, dpi=600)
    plt.show()

# Load the WFDB record and the physical samples
record = wfdb.rdrecord(ecg_path[0], sampfrom=0, sampto=10000, channels=[0])

# Use the GQRS algorithm to detect QRS locations in the first channel
qrs_inds = processing.qrs.gqrs_detect(sig=record.p_signal[:,0], fs=record.fs)

# Plot results
peaks_hr(sig=record.p_signal, peak_inds=qrs_inds, fs=record.fs,
         title="GQRS peak detection")
    
# Correct the peaks shifting them to local maxima
min_bpm = 20
max_bpm = 230
#min_gap = record.fs * 60 / min_bpm
# Use the maximum possible bpm as the search radius
search_radius = int(record.fs * 60 / max_bpm)
corrected_peak_inds = processing.peaks.correct_peaks(record.p_signal[:,0], 
                                                     peak_inds=qrs_inds,
                                                     search_radius=search_radius, 
                                                     smooth_window_size=150)

# Display results
print('Corrected GQRS detected peak indices:', sorted(corrected_peak_inds))
peaks_hr(sig=record.p_signal, peak_inds=sorted(corrected_peak_inds), fs=record.fs,
         title="Corrected GQRS peak detection")
# Out:
# C:\Users\dd\AppData\Local\Temp\ipykernel_6260\2951821436.py:12: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "rx" (-> marker='x'). The keyword argument will take precedence.
#   ax_left.plot(peak_inds, sig[peak_inds], 'rx', marker='x',
# C:\Users\dd\AppData\Local\Temp\ipykernel_6260\2951821436.py:12: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "rx" (-> color='r'). The keyword argument will take precedence.
#   ax_left.plot(peak_inds, sig[peak_inds], 'rx', marker='x',
# Corrected GQRS detected peak indices: [136, 230, 325, 419, 514, 610, 706, 804, 902, 999, 1095, 1192, 1289, 1385, 1482, 1577, 1673, 1769, 1864, 1959, 2054, 2148, 2242, 2335, 2429, 2523, 2616, 2709, 2802, 2894, 2986, 3079, 3173, 3266, 3358, 3451, 3544, 3635, 3727, 3819, 3911, 4003, 4094, 4186, 4277, 4369, 4460, 4551, 4643, 4734, 4825, 4916, 5008, 5100, 5193, 5285, 5379, 5475, 5571, 5667, 5763, 5859, 5955, 6051, 6146, 6241, 6335, 6429, 6523, 6617, 6711, 6805, 6898, 6991, 7085, 7178, 7271, 7363, 7456, 7548, 7641, 7734, 7826, 7919, 8011, 8103, 8196, 8288, 8380, 8472, 8563, 8656, 8749, 8841, 8933, 9024, 9116, 9208, 9300, 9392, 9481, 9573, 9663, 9754, 9845, 9936]
